# %%
import numpy as np
import pandas as pd
import requests
import time
import json

api_key = 'RGAPI-6e04b0e4-7f98-4a36-8f13-6494583b4964'

request_header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36",
    "Accept-Language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
    "Accept-Charset": "application/x-www-form-urlencoded; charset=UTF-8",
    "Origin": "https://developer.riotgames.com",
    "X-Riot-Token": api_key
}

base_url = "https://kr.api.riotgames.com/tft/"

# %%
'''
(1) summonerid : 유저 id code, String이다.

(2) summonerName : 게임에서 사용하고 있는 유저의 id, String이다.

(3) leaguePoints : 현재 rank 점수, int이다.

(4) rank : rank. 챌린저이므로 모든 유저가 'I'.

(5) wins : 이번 rank 측정 기간 중 승리 수, int이다.

(6) losses : 이번 rank 측정 기간 중 패배 수, int이다.

(7) veteran : 베테랑 유무. (이번 시즌 게임 수가 100회 이상이면 베테랑), Boolean이다.

(8) inactive : 최근 게임 참여 적극성, Boolean이다.

(9) freshBlood : 이번 시즌이 첫 시즌인 경우 T, Boolean이다.

(10) hotStreak : 3연승 이상 중, Boolean이다.
'''
challenger_url = base_url + 'league/v1/challenger'
challenger = requests.get(challenger_url, headers=request_header).json()

# url 응답상태 확인 코드
# print(challenger.status_code)

challenger_df = pd.DataFrame(challenger['entries'])
print(challenger_df)
challenger_df.to_excel('test.xlsx')
# Out:
#                                             summonerId  \
# 0     GYpEe07LBmd7GybNpSoe2-fgdYMSzVmMagNxg4ciENaw6sDT
# 1      quWqFkt--TijmVjtjxEGffcnV6JnBrUnnXTjRB5vIypA87Y
# 2    _OCDEHX56EE6u0XCMNIN_iptDCxcMLSIDjh8nCk9J4AQmq...
# 3    wDIm1t534qs2jjQYLYjbE_FM1PBhNWjy0hvQkNPcbpgETN...
# 4    K4MlDPgSz-CVS8bO-6I1IOGoTP8MNGROw82mH5ikDY0Cr2...
# ..                                                 ...
# 295  w_is74kY6QG_HkYb7lvFB0pE1ulO7tLCYBDtnjxYpBe1jI...
# 296  HhrdU3xTy8m2b3FKUvG-Fqow83xVH9IiaSoSiLCJlXcU4T...
# 297    IOrGSzsaMDMw-oYiqmJ_hT8lfgOXBcbOA_ldVSXhG7jJCjo
# 298  _HCHdfKAJAIX500iRSz1GXtQBmm9-ur6dyOKUQdsXLVkS_...
# 299  k1Hu7PGKw8RLVX9H8Pm2syC5tDgtH2ThuaUloh_sD0Ef1u...
#
#                                                  puuid  leaguePoints rank  \
# 0    4up9RrUC7olP4EwQfrAK27cSAX-SdTybr8KVkn5TG9n_60...          1783    I
# 1    3eDtpya9tImZkaBw_CRlfMORSvVdIGyXSfCV9W7KfdJ0wu...          1759    I
# 2    pAYrlIR6VQHTacprZQk9iCaJda-ko0RTgH2aL78qG40pa3...          1666    I
# 3    BpGfVRZyengTc2vPQ1ueGqe52Q2lPUsCNMTE-MRDl8DAKz...          1612    I
# 4    x09y6MrvUVvcQlW2mri3OrJUXdn1-6FQSLl18H76t-zh6c...          1602    I
# ..                                                 ...           ...  ...
# 295  G-yt49Y6yzle3bZC_RIDyvXvolhy_RyDrkNtC6JvNyMtkY...          1065    I
# 296  gBJGAIHqphwTHhTosD5DQSaPkPdM0NJtCRAwmqWTsGsKt7...          1053    I
# 297  wE6eVZnZNn60XZ4MUFgc7-edYdZX0b7b48EmunMmsyy-bk...          1038    I
# 298  NlFdJ-bpXF0l43zFitPptJKWKE3136EcIBgq4E8quB2zp9...          1006    I
# 299  UQNE8I47MemdIqIsL0390UwrdtZy3vrpZx0S75AH9WFPr0...           825    I
#
#      wins  losses  veteran  inactive  freshBlood  hotStreak
# 0     537     354     True     False       False       True
# 1     791     526    False     False       False       True
# 2     479     334     True     False       False      False
# 3     352     184     True     False       False      False
# 4     795     700    False     False       False       True
# ..    ...     ...      ...       ...         ...        ...
# 295   370     289    False     False        True      False
# 296   407     331    False     False       False      False
# 297   408     339    False     False       False      False
# 298   436     370    False     False        True      False
# 299   611     466    False     False        True      False
#
# [300 rows x 10 columns]

# %%
grandmaster_url = base_url + 'league/v1/grandmaster'
grandmaster = requests.get(grandmaster_url, headers=request_header).json()

# url 응답상태 확인 코드
# print(challenger.status_code)

grandmaster_df = pd.DataFrame(grandmaster['entries'])
print(grandmaster_df)
# Out:
#                                             summonerId  \
# 0       F4yjmxdgBgO-NQ6UHBJei0_WRqgOTS7xdQF_C7TA7RJdcA
# 1    bfI37qaNUsU4hKmqB6O3PjgqNlA44E4Tg0-P6j3mBRc_U-...
# 2    jNuDZIyz6dGI0tz_GqkFDV1hoy62fkvSuTezO1Wc9aPinY...
# 3    LWC20MnANsJdfAzz7JO87YRntn2DRisMe7wac6OR6Vpyxl...
# 4      IXM2YLQG41jIhiaSDRhikPnRNqimUriVVaufK2XisJcv3qc
# ..                                                 ...
# 595    ZfXnUonV48L6I64QMp0yVtKCskIdiQzvKHVHkRXi36HXKY0
# 596   jgCuW30lxkIVRTmeJGfKel2bjFVA6aWIRF3GDRWnsV5kYsqF
# 597    8f2SDm7Hm0xmc9azdXWUptIWFJYruvOnhbuREHG4ruLt4PA
# 598     srGuVGNDfWVCHro_qS6liGfnTcLWheUq5JmHiQ9YkXxK8A
# 599     EVSuacHAS_V_PRqi7zri2cFFbBKJEA70FMs-E0OQzrJnVA
#
#                                                  puuid  leaguePoints rank  \
# 0    hNdIKncU5L5wc1aQvl7vJ5DZtJ6Tvlp5Xost2DG154GLK4...          1278    I
# 1    cVQrWbuuJR4G6bBvQ6HygKu0HnxZEX8T0t18WbfqCf3R1F...          1244    I
# 2    DsLy1W5xHb-B7Sl922eh1Ask0lx-BmBoYv916g7U68aSzp...          1230    I
# 3    X3ILla8DlwMaHTmmNx4679XMWBQj4nXDoyF8k4DrfLducj...          1229    I
# 4    TNCo3i4_CltxlRbzYi-Tyb4B3MZjchA4epLrQ6dhU4WcqB...          1206    I
# ..                                                 ...           ...  ...
# 595  JbNSgYBtNsJvbSQld8EYvY9zFs0HHBjihklSceSfryR9QX...           676    I
# 596  DnXFAp1EpxPqTPRrLJUHQ18qGStXprN5_X4exLvgz5F0vu...           637    I
# 597  5PtbuhXE6mN8oUe6A62gu4VW8RF1Qcc9c_5XtT6DoIJBMS...           598    I
# 598  OFnrFx7jm4cKY1O5CzBQmcFllPb3NJaKdi7VbJWv_cg6on...           585    I
# 599  R2SzRLGfyqoeS-yzpiLgj7qYh4sQo5sbmWgbgjqW2bZ7wn...           518    I
#
#      wins  losses  veteran  inactive  freshBlood  hotStreak
# 0     423     315    False     False        True       True
# 1     244     183    False     False        True       True
# 2     230     158    False     False        True       True
# 3     285     189    False     False        True       True
# 4     266     208    False     False        True       True
# ..    ...     ...      ...       ...         ...        ...
# 595   221     173    False     False        True      False
# 596   512     438    False     False        True      False
# 597   770     749    False     False        True      False
# 598   496     443    False     False        True      False
# 599   221     186    False     False       False      False
#
# [600 rows x 10 columns]

# %%
master_url = base_url + 'league/v1/master'
master = requests.get(master_url, headers=request_header).json()

# url 응답상태 확인 코드
# print(challenger.status_code)

master_df = pd.DataFrame(master['entries'])
print(master_df)
# Out:
#                                              summonerId  \
# 0       hREJAtM4wC_mR6VXJbNWycKFNSIr_YayXl2DxeAFmnCMzH0
# 1     vXe5XrZ2bsynDgrudtTeVdpIp2wxbhMeASQ7CFpkQ6urI_...
# 2        hh_YdFJJKBy53K9UJeYQVGkGxrKdT8z39Aa4qTTiyaB2LQ
# 3       qbMZl-QkFrzOX6A4BEVym4aHJO7qP3dbRh3cdKRYwg6l6ng
# 4        xzswuyP19RNaKvlqiZKJIFbhkkBLifxp-eVh6jNdgRKaCA
# ...                                                 ...
# 9995     RAjex9GcXQlxQAxpq3U1Y6vJFcwIbk9cfbycNXub5xGEMA
# 9996  pdFum3nkb4rX3V9Hoc2jQOsQ3bnNmtYsabvHoYgQnRwbZB...
# 9997  K33h9HmXEdUTnruji2BM-BR50ynvr6wI6c5ipGSdUe2_0L...
# 9998    sx1_v9yMpWnFnc520VunoECqJnjs7Plz6DpLNsxFXW7yE-Y
# 9999    riIHgoWoumCqNmuPpakaIpZLv0uPrIvKy-J4_bjE5vjRy8U
#
#                                                   puuid  leaguePoints rank  \
# 0     HH0AvVPITJCpZ_C5QsDUg9NE1T8_Zw_JAhfoKtVPp6GsJh...          1043    I
# 1     M0Udhdk6vYU2EjkAAwYOPBTm_oB2aPFYJieC8tZoTJjCZY...           962    I
# 2     Y4wxFXH-vTzIQ2qqVS5WH2Tx2umOFE1CIuBEjZaJsjlCcZ...           962    I
# 3     xO5gw-EI73UJdRQ4_6Fe2XWzK6Q409yPrdaswrz1ETCzui...           943    I
# 4     HKJpwcc4WmTAvmb-654oACn33U22jMgr3ifY5Dew2dkJQA...           909    I
# ...                                                 ...           ...  ...
# 9995  b7Pf7rCD1KuS6IrCfwLKpemKMIfig-a6-77g4fPIINzie7...            80    I
# 9996  n1n5VyM9wPy35UZfRee06U6p3vO_eavTJlPS5kTPZ3mEtV...            80    I
# 9997  fIWiKYLK10qHm_3NU0xgGl53O0rZuwMn_6ijC6iebJwSOF...            80    I
# 9998  NOX5Lbz_IYvo7kP8O2IqzfPOm2emDRxE3vyOA_naQRwnVL...            80    I
# 9999  JeU_cLgTI_qRZRmerEpgp07ykReZ7NiyisVfEgYtKxklEi...            80    I
#
#       wins  losses  veteran  inactive  freshBlood  hotStreak
# 0      585     555     True     False       False      False
# 1      562     508    False     False        True       True
# 2      184     124    False     False        True       True
# 3      507     484    False     False        True       True
# 4      223     173     True     False       False       True
# ...    ...     ...      ...       ...         ...        ...
# 9995   297     274    False     False       False      False
# 9996   296     261    False     False       False      False
# 9997   293     234     True     False       False      False
# 9998   289     259     True     False       False      False
# 9999   278     264    False     False       False      False
#
# [10000 rows x 10 columns]

# %%
'''
페이지마다 205명의 유저 정보가 존재하는데 
page가 바뀔 때 이전 page의 후반 5명 정보부터 데이터가 이어진다. 
(따라서, 한 페이지 당 200명의 유저 정보가 들어있다.)

Challenger 데이터에서 3개의 key가 추가된다.

1) leagueId : 해당 유저가 속한 리그 아이디, String이다.

2) queryType : queryType으로 rank와 초고속모드 rank로 나뉘어져 있다.

3) tier : 해당 유저 티어, 아이언~다이아몬드를 선택할 수 있기 때문에, 해당 key를 통해 어떤 티어에 속하는지 확인할 수 있도록 했다.
'''
dia1_page1_url = base_url + 'league/v1/entries/DIAMOND/I?queue=RANKED_TFT&page=1'
dia1_page1 = requests.get(dia1_page1_url, headers = request_header).json()

dia1_page1_df = pd.DataFrame(dia1_page1)
print(dia1_page1_df)
# Out:
#                                                  puuid  \
# 0    3oU7-Qs08P7VE4JDVwZgsFOXuk1JMTj5i4DBkGXef8-evt...
# 1    it0_Fyaa198mCNkiDcro5IFd4HOWmSz99Ra5EVZY_i2215...
# 2    Y7uQ1iAHrOWS_-vd9ofW2hBZZYba9UGMqXUEh-owo9lIpK...
# 3    1GdbJZmRUtvmN535obJbg9O4TgLVJQsaHAQcY25e96_4l9...
# 4    o7S_dKLV1WxBWoMWeDrd_AgUGKQ5gGc5P9nCBqsRrz41DL...
# ..                                                 ...
# 200  X2UA28SoEvhXwtiCc_j1mk06DEQ-5ppGz1IayxqFJj4A6U...
# 201  6EhU5I-wyUVEL5wf1Yr5Q35RVD1sDYuWyGpuvmbZN7lmqU...
# 202  BfRK3qEgUU9zkrJ3vqacVYWzVdRACdBBSLnT9nMuxS9D4L...
# 203  fjhJrZ5Ax0i0waqQyIape8am1iA8-TIpvpuxKKTmUhmXoO...
# 204  oOPTw9niRcvxG2soox4-axT4_qISFwBkeZLf6uMtc3Wxak...
#
#                                  leagueId   queueType     tier rank  \
# 0    4916021b-634d-4a4f-aeac-37663a3a9368  RANKED_TFT  DIAMOND    I
# 1    91e07df2-c8ba-4b41-8f98-6aa8d3be63f6  RANKED_TFT  DIAMOND    I
# 2    2ab15cf3-3015-43b9-8276-002237960f72  RANKED_TFT  DIAMOND    I
# 3    cf1b064a-2ee9-4f6b-84cc-76297212a800  RANKED_TFT  DIAMOND    I
# 4    12e2b06c-029f-4842-b934-67249b2664d1  RANKED_TFT  DIAMOND    I
# ..                                    ...         ...      ...  ...
# 200  cb4bd68d-075a-43d7-bc4b-b597f8acc2c0  RANKED_TFT  DIAMOND    I
# 201  bc006c1c-f660-402a-ab5f-4ace31640364  RANKED_TFT  DIAMOND    I
# 202  c1fbbffc-a68f-409d-a295-aec72076eebb  RANKED_TFT  DIAMOND    I
# 203  89acaad2-a07d-4688-8aeb-c66a0df94abe  RANKED_TFT  DIAMOND    I
# 204  3ddaf3d2-bcff-4328-a55b-44d4b1852bea  RANKED_TFT  DIAMOND    I
#
#                                            summonerId  leaguePoints  wins  \
# 0    W-mzC7_2CvmkPURCvWxXPZ8E1O0APoLSdsmHO6tJU3MKh9K6            98   133
# 1    5VqyorPNFb64ppb_6a_kcTf-AixbiarZC9DLqiTolGjW53J_             0   121
# 2    4J4Jd_CQTwFtKtzRT6FnL73iMWzIY28D8dOwNc2IQRpwOWPq            27   146
# 3    k2a_85U_dE7nxajkyRQYxAPBqWsDheUAw1A-sXlMVrOe3pNJ            93   176
# 4    8BdIvW5mxPoR0p75Kb5JLJbCioNoy5UeopL1MsLsgzqSU_Pv             2    88
# ..                                                ...           ...   ...
# 200   uP0sGMWu5CS1iow3wXlSfJP4IQZNkc9UP3y6MUrwEf6_I_g             4   188
# 201   BVNr31YJnRlsgJjYLsVhA02byhjQLVS7Uir2X_FEZ0d4kkI            14   221
# 202    EVnu6gMYVCV8E_M8MI2bAHqQswbDBgDeYxSk4tKOw3korA            21   163
# 203   BfBpsbfjO6N-95aD7IPAdzEhTUFKIsLMWbP75J23RvmihRA            15    82
# 204   NLqdqbl_bi-JQ8IfuVY6ix6kRp-LkoSXo8-Q_U8L8KT4NAM            56   239
#
#      losses  veteran  inactive  freshBlood  hotStreak
# 0       109    False     False       False      False
# 1       118    False     False       False      False
# 2       133    False     False       False       True
# 3       159    False     False       False       True
# 4        50    False     False       False       True
# ..      ...      ...       ...         ...        ...
# 200     170    False     False       False      False
# 201     163    False     False       False       True
# 202     135    False     False       False      False
# 203      61    False     False       False      False
# 204     196    False     False       False      False
#
# [205 rows x 13 columns]
